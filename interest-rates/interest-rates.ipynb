# %%
import handcalcs.render as render
from handcalcs import handcalc

# %%
amount = 10800
main_capital = 10000
fees = amount - main_capital

# %%
interest_rate = 100 * (amount / main_capital - 1) #percentage

# %%
# Function for simple discrete capitation regime
def amount_sd(main_capital, interest_rate, period):
  SD = (1 + period * interest_rate / 100) * main_capital
  return SD

# %%
# Applying function for simple discrete capitation regime
main_capital = 20000
period = 5
interest_rate = 7
SD = amount_sd(main_capital, interest_rate, period)
# Out:
# 27000.0
