# %%
import handcalcs.render as render
from handcalcs import handcalc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-286d106c8cc3> in <module>
# ----> 1 import handcalcs.render as render
#       2 from handcalcs import handcalc
#
# ModuleNotFoundError: No module named 'handcalcs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
amount = 10800
main_capital = 10000
simple_interest = amount - main_capital

# %%
simple_interest_rate = 100 * (amount / main_capital - 1) #percentage
# Out:
# 8.000000000000007
